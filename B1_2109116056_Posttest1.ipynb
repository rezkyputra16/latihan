# %% [markdown]
# <a href="https://colab.research.google.com/github/rezkyputra16/latihan/blob/main/B1_2109116056_Posttest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NIM **2109116056**
#
# NAMA **REZKY PUTRA KURNIAWAN**

# %%
#import library
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
#mengupload file csv
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b8c43735-7a6f-4ebc-a422-526a4f47f50b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8c43735-7a6f-4ebc-a422-526a4f47f50b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Sebagai seorang direktur perusahaan, tujuan saya menggunakan dataset ini mungkin untuk menganalisis pasar atau untuk membuat strategi pemasaran yang lebih baik untuk perusahaan saya. Dataset yang digunakan mungkin berisi informasi tentang perilaku konsumen, data demografi, atau informasi produk. Dengan menganalisis dataset ini, saya dapat mengidentifikasi tren pasar, preferensi konsumen, dan kekuatan dan kelemahan produk kami.
#
# Tujuan perusahaan saya mungkin adalah untuk meningkatkan penjualan atau pangsa pasar kami, atau untuk meningkatkan kesadaran merek kami. Dengan menggunakan algoritma Naive Bayes, saya dapat memprediksi kemungkinan sukses dari berbagai strategi pemasaran atau iklan, serta mengidentifikasi segmen pasar yang paling berpotensi untuk membeli produk kami.

# %%
#menampilkan file yang telah diupload
df = pd.read_csv('ChurnBank.csv')
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %%
#histogram untuk customer age
sns.histplot(data=df, x="Customer_Age", kde=True)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
#histogram untuk credit card limit
sns.histplot(data=df, x="Credit_Limit", kde=True)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
#boxplot untuk customer age
sns.boxplot(data=df,x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %%
#boxplot untuk customer
sns.boxplot(data=df,x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
#comparison attrited customer and existing customer
customer = [np.count_nonzero(df['Attrition_Flag'] == 'Attrited Customer'), np.count_nonzero(df['Attrition_Flag'] == 'Existing Customer')]
label = ['Attrited', 'Existing']
plt.title('attrited customer and existing customer dengan total 20 data')
plt.pie(customer, labels = label, radius=1, autopct=lambda p: '{:.1f}%'.format(p))
plt.show()

# %%
#visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
sns.countplot(data=df,y="Education_Level")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %%
#visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
sns.countplot(data=df, y='Education_Level', hue="Gender");

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %%
df1 = df[df["Attrition_Flag"].str.contains('Attrited Customer')]
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
df2 = df[~df['Attrition_Flag'].str.contains('Attrited Customer')]
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
df3 = df[df["Customer_Age"] < 50]
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
df4 = df[df["Marital_Status"].str.contains('Single')]
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
sns.countplot(data=df, y='Education_Level')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %%
#scatterplot untuk umur customer dan credit card limit
sns.scatterplot(data=df,x="Customer_Age", y="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %%
#pieplot untuk Education level
px.pie(df, names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#pieplot untuk Income Category
px.pie(df, names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# OPSIONAL

# %%
# Menampilkan kolom bertipe angka
df5= df[['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit']]
df5
# Out:
#     Unnamed: 0  CLIENTNUM  Customer_Age  Credit_Limit
# 0         6036  720010608            37       10226.0
# 1         6684  711323283            57        2527.0
# 2         4272  794707083            50        3495.0
# 3         9759  709657533            44        7793.0
# 4         4740  716625033            32        2761.0
# 5         9597  715076358            57       23714.0
# 6         5009  804829533            59       24621.0
# 7         8200  712144158            53        2370.0
# 8         5016  795599883            57        2404.0
# 9         8350  709222008            41        4742.0
# 10        8139  809844108            48        8086.0
# 11         176  716264358            53       26792.0
# 12        8020  778163508            37        5245.0
# 13         357  711857733            49       18584.0
# 14        6562  720070383            41        2429.0
# 15        4563  809809008            47        3111.0
# ...

# %%
# Menampilkan nilai rata-rata Kolom yang bertipe angka
df5.mean()
# Out:
# Unnamed: 0      6.105100e+03
# CLIENTNUM       7.424893e+08
# Customer_Age    4.725000e+01
# Credit_Limit    8.114580e+03
# dtype: float64

# %%
# Menampilkan nilai min Kolom yang bertipe angka
df5.min()
# Out:
# Unnamed: 0            176.0
# CLIENTNUM       709222008.0
# Customer_Age           32.0
# Credit_Limit         1438.3
# dtype: float64

# %%
# Menampilkan nilai max Kolom yang bertipe angka
df5.max()
# Out:
# Unnamed: 0          10084.0
# CLIENTNUM       809844108.0
# Customer_Age           59.0
# Credit_Limit        26792.0
# dtype: float64

# %%
# Menampilkan nilai standar deviasi Kolom yang bertipe angka
df5.std()
# Out:
# Unnamed: 0      2.850304e+03
# CLIENTNUM       4.045524e+07
# Customer_Age    7.859791e+00
# Credit_Limit    8.331037e+03
# dtype: float64

# %%
#visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya menggunakan warna
plt.figure(figsize=(8,6))
sns.boxplot(x="Credit_Limit", data=df, hue="Gender", color="blue")
plt.title('Boxplot Credit Card Limit dengan Jenis Kelamin')
plt.show()

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya menggunakan warna
plt.figure(figsize=(8,6))
sns.boxplot(x="Attrition_Flag", y="Credit_Limit", data=df, hue="Attrition_Flag")
plt.title('Boxplot Credit Card Limit dengan Attrition Flag')
plt.show()

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya menggunakan warna
plt.figure(figsize=(8,6))
sns.boxplot(x="Attrition_Flag", y="Customer_Age", data=df, hue="Attrition_Flag")
plt.title('Boxplot Age dengan Attrition Flag')
plt.show()

# %%
#visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya menggunakan warna
plt.figure(figsize=(8,6))
sns.countplot(data=df,x="Attrition_Flag", hue="Gender")
plt.title('Countplot  Attrition Flag dengan jenis kelamin')
plt.show()

# %%
#visualisasi heatmap untuk Setiap variabel numerik 
sns.heatmap(
    df[['Unnamed: 0','CLIENTNUM','Customer_Age','Credit_Limit']].corr(),
    annot=True,
    center=0,);
plt.title('Heatmap untuk Setiap variabel numerik')
plt.show()

# %%
import numpy as np
import pandas as pd

#membaca data yang akan di training
data_train = pd.read_csv('ChurnBankSorted.csv')

#menghitung jumlah data training dan testing 
N_train = len(data_train)

#menghitung jumlah kelas targer 
target_counts = data_train.groupby('Attrition_Flag')['Attrition_Flag'].count()

#menghitung probabilitas priori setiap kelas target
prior_prob = target_counts / N_train

#menghitung probabilitas kondisional setiap fitur pada setiap kelas target
cond_prob = {}
for col in data_train.columns[:-1]:
    cond_prob[col] = {}
    for val in data_train[col].unique():
        for target in data_train['Attrition_Flag'].unique():
            count = len(data_train[(data_train[col] == val) & (data_train['Attrition_Flag'] == target)])
            cond_prob[col][(val, target)] = count / target_counts[target]

#naive bayes
def naive_bayes(x):
    prob_yes = prior_prob['Attrited Customer']
    prob_no = prior_prob['Existing Customer']
    for i, col in enumerate(data_train.columns[:-1]):
        try:
          prob_yes *= cond_prob[col][(x[i], 'Attrited Customer')]
          prob_no *= cond_prob[col][(x[i], 'Existing Customer')]
        except IndexError:
            return "Error: the input features are not compatible with the training data"
    if prob_no > prob_yes:
        return ('Existing Customer', prob_no)
    else:
        return ('Attrited Customer', prob_yes)

#penggunaan fungsi naive_bayes
output = naive_bayes(["F",	"Uneducated","Single", "Unknown","Blue"])
output
